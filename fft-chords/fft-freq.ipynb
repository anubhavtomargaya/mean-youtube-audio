# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/present/blob/master/youtube/video/fft-frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Copyright 2022 by [Jeff Heaton](https://www.heatonresearch.com/), released under [LGPLv3](https://www.gnu.org/licenses/lgpl-3.0.en.html)
#
# [YouTube video about this code](https://www.youtube.com/watch?v=rj9NOiFLxWA)

# %%
# try:
#     from google.colab import drive
#     drive.mount('/content/drive', force_remount=True)
#     COLAB = True
#     print("Note: using Google CoLab")
# except:
#     print("Note: not using Google CoLab")
#     COLAB = False

# PATH = '/content/drive/MyDrive/projects/audio'

# !pip install -U kaleido

# Configuration
FPS = 30
FFT_WINDOW_SECONDS = 0.25 # how many seconds of audio make up an FFT window

# Note range to display
FREQ_MIN = 10
FREQ_MAX = 1000

# Notes to display
TOP_NOTES = 3

# Names of the notes
NOTE_NAMES = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]

# Output size. Generally use SCALE for higher res, unless you need a non-standard aspect ratio.
RESOLUTION = (1920, 1080)
SCALE = 2 # 0.5=QHD(960x540), 1=HD(1920x1080), 2=4K(3840x2160)
# Out:
# Requirement already satisfied: kaleido in ./.venv/lib/python3.10/site-packages (0.2.1)
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile # get the api
import os

# Get a WAV file from GDrive, such as:
# AUDIO_FILE = os.path.join(PATH,'short_popcorn.wav')

# Or download my sample audio
# !wget https://github.com/jeffheaton/present/raw/master/youtube/video/sample_audio/piano_c_major_scale.wav
AUDIO_FILE = "./sample_audio/metroo.wav"

fs, data = wavfile.read(AUDIO_FILE) # load the data
audio = data.T[0] # this is a two channel soundtrack, get the first track
FRAME_STEP = (fs / FPS) # audio samples per video frame
FFT_WINDOW_SIZE = int(fs * FFT_WINDOW_SECONDS)
AUDIO_LENGTH = len(audio)/fs

# %% [markdown]
# Several utility functions.

# %%
import plotly.graph_objects as go
import numpy as np
def plot_fft(p, xf, fs, notes, dimensions=(960,540)):
  layout = go.Layout(
      title="frequency spectrum",
      autosize=False,
      width=dimensions[0],
      height=dimensions[1],
      xaxis_title="Frequency (note)",
      yaxis_title="Magnitude",
      font={'size' : 24}
  )

  fig = go.Figure(layout=layout,
                  layout_xaxis_range=[FREQ_MIN,FREQ_MAX],
                  layout_yaxis_range=[0,1]
                  )
  
  fig.add_trace(go.Scatter(
      x = xf,
      y = p))
  
  for note in notes:
    fig.add_annotation(x=note[0]+10, y=note[2],
            text=note[1],
            font = {'size' : 48},
            showarrow=False)
  return fig

def extract_sample(audio, frame_number):
  end = frame_number * FRAME_OFFSET
  begin = int(end - FFT_WINDOW_SIZE)

  if end == 0:
    # We have no audio yet, return all zeros (very beginning)
    return np.zeros((np.abs(begin)),dtype=float)
  elif begin<0:
    # We have some audio, padd with zeros
    return np.concatenate([np.zeros((np.abs(begin)),dtype=float),audio[0:end]])
  else:
    # Usually this happens, return the next sample
    return audio[begin:end]

def find_top_notes(fft,num):
  if np.max(fft.real)<0.001:
    return []

  lst = [x for x in enumerate(fft.real)]
  lst = sorted(lst, key=lambda x: x[1],reverse=True)

  idx = 0
  found = []
  found_note = set()
  while( (idx<len(lst)) and (len(found)<num) ):
    f = xf[lst[idx][0]]
    y = lst[idx][1]
    n = freq_to_number(f)
    n0 = int(round(n))
    name = note_name(n0)

    if name not in found_note:
      found_note.add(name)
      s = [f,note_name(n0),y]
      found.append(s)
    idx += 1
    
  return found

# %% [markdown]
# Run the FFT on individual samples of the audio and generate video frames of the frequency chart.

# %%
import numpy as np
import tqdm

# !rm /content/*.png

# See https://newt.phys.unsw.edu.au/jw/notes.html
def freq_to_number(f): return 69 + 12*np.log2(f/440.0)
def number_to_freq(n): return 440 * 2.0**((n-69)/12.0)
def note_name(n): return NOTE_NAMES[n % 12] + str(int(n/12 - 1))

# Hanning window function
window = 0.5 * (1 - np.cos(np.linspace(0, 2*np.pi, FFT_WINDOW_SIZE, False)))

xf = np.fft.rfftfreq(FFT_WINDOW_SIZE, 1/fs)
FRAME_COUNT = int(AUDIO_LENGTH*FPS)
FRAME_OFFSET = int(len(audio)/FRAME_COUNT)

# Pass 1, find out the maximum amplitude so we can scale.
mx = 0
for frame_number in range(FRAME_COUNT):
  sample = extract_sample(audio, frame_number)

  fft = np.fft.rfft(sample * window)
  fft = np.abs(fft).real 
  mx = max(np.max(fft),mx)

print(f"Max amplitude: {mx}")

# Pass 2, produce the animation
for frame_number in tqdm.tqdm(range(FRAME_COUNT)):
  sample = extract_sample(audio, frame_number)

  fft = np.fft.rfft(sample * window)
  fft = np.abs(fft) / mx 
     
  s = find_top_notes(fft,TOP_NOTES)

  fig = plot_fft(fft.real,xf,fs,s,RESOLUTION)
  fig.write_image(f"./content/frame{frame_number}.png",scale=2)
# Out:
# rm: /content/*.png: No such file or directory
# Max amplitude: 37256140.72624145
# 100%|██████████| 444/444 [01:29<00:00,  4.97it/s]

# %% [markdown]
# Use [ffmpeg](https://ffmpeg.org/) to combine the input audio WAV and the individual frame images into a MP4 video.

# %%
# !brew install ffmpeg
# Out:
# Running `brew update --auto-update`...
# ==> You have set:
#   HOMEBREW_NO_INSTALL_FROM_API
# but we have dramatically sped up and fixed many bugs in the way we do Homebrew updates since.
# Please consider unsetting these and tweaking the values based on the new behaviour.
#
#
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# aarch64-elf-gdb                          llm
# access                                   llvm@14
# ada-url                                  llvm@15
# adb-enhanced                             lmfit
# adr-viewer                               lowdown
# aerleon                                  lpeg
# aftman                                   lr
# agg                                      ls-lint
# aichat                                   luacheck
# aicommits                                lucky-commit
# aiven-client                             lune
# akku                                     lxi-tools
# alass                                    m1ddc
# aliyunpan                                macpine
# amber                                    mailpit
# ancient                                  mailsy
# animdl                                   mariadb@10.10
# ansible@6                                mariadb@10.11
# ansible@7                                mariadb@10.8
# antidote                                 mariadb@10.9
# apify-cli                                mariadb@11.0
# apko                                     markdownlint-cli2
# apophenia                                marksman
# apprise                                  massdriver
# aptos                                    mdless
# ares                                     mdt
# argparse                                 medusa
# aribb24                                  melange
# arjun                                    meson-python
# arm-none-eabi-binutils                   meta-package-manager
# arm-none-eabi-gcc                        metals
# arm-none-eabi-gdb                        metview
# arttime                                  mfem
# asn                                      mgis
# asnmap                                   micromamba
# ast-grep                                 millet
# astgen                                   mimirtool
# ata                                      minigraph
# autocorrect                              mjml
# aws-amplify                              mods
# aws-sam-cli                              modsecurity
# aws-sso-cli                              mpfrcx
# bacon                                    mqttui
# base16384                                mtbl
# bashate                                  muon
# bazarr                                   musikcube
# bazel-diff                               mvfst
# bazel-remote                             mvt
# bbot                                     mxnet
# bdftopcf                                 mycorrhiza
# benerator                                mysql-client@8.0
# bfs                                      mysql@8.0
# bilix                                    naga-cli
# bindgen                                  nap
# blades                                   nemu
# blink                                    neonctl
# blocky                                   nerdfix
# boolector                                netcdf-cxx
# bossa                                    netcdf-fortran
# botan@2                                  nexttrace
# brpc                                     nixpacks
# btrfs-progs                              notation
# buf                                      notify
# burst                                    ntbtls
# busted                                   ntfy
# bwidget                                  nuraft
# bzip3                                    oauth2c
# c                                        objconv
# camlp-streams                            ocm
# cargo-about                              ocmtoc
# cargo-all-features                       octobuild
# cargo-auditable                          okta-aws-cli
# cargo-binstall                           okta-awscli
# cargo-binutils                           ol
# cargo-deny                               ollama
# cargo-deps                               opal
# cargo-docset                             openai-whisper
# cargo-generate                           opencl-clhpp-headers
# cargo-make                               opencl-icd-loader
# cargo-release                            openfga
# cargo-zigbuild                           openiked
# cascadia                                 openssl@3.0
# cbindgen                                 openvino
# cbonsai                                  orbiton
# cdebug                                   orcania
# cdi                                      ord
# cdsclient                                osv-scanner
# cdxgen                                   ouch
# censys                                   pandemics
# cffi                                     papilo
# chaoskube                                pari-nflistdata
# charls                                   pbzx
# chatblade                                pdf-diff
# check-jsonschema                         pferd
# checkdmarc                               pfetch-rs
# clang-build-analyzer                     pgrok
# clifm                                    pgsync
# clipboard                                pgvector
# clitest                                  phoneinfoga
# clive                                    php@8.1
# cloud-sql-proxy                          picotool
# cloudflare-wrangler2                     pinocchio
# cloudfox                                 pipdeptree
# cloudlist                                pixi
# cloudpan189-go                           plog
# cloudprober                              pluto
# clusterawsadm                            plz-cli
# cmctl                                    pmtiles
# cntb                                     pocketbase
# cocogitto                                podsync
# code-cli                                 poke
# codelimit                                pomsky
# coder                                    pop
# cog                                      popeye
# colmap                                   portablegl
# commitlint                               portal
# conan@1                                  postgresql@15
# conda-lock                               postgresql@16
# conda-zsh-completion                     powerlevel10k
# conduit                                  prettierd
# conman                                   procps@3
# convco                                   protobuf@21
# copa                                     protolint
# core-lightning                           prowler
# corrosion                                proxify
# couchbase-shell                          proxsuite
# countdown                                proxygen
# counts                                   prs
# cppinsights                              psysh
# cpuid                                    purescript-language-server
# cql-proxy                                pwned
# crabz                                    pycparser
# crfsuite                                 pygit2
# cryptopp                                 pylyzer
# crystalline                              pymol
# crytic-compile                           pypy3.10
# ctpv                                     pypy3.9
# curlcpp                                  pyspelling
# cyclonedx-gomod                          pystring
# cyclonedx-python                         python-certifi
# cycode                                   python-click
# czkawka                                  python-cryptography
# d2                                       python-flit-core
# ddns-go                                  python-gdbm@3.11
# debugbreak                               python-lsp-server
# define                                   python-lxml
# devcontainer                             python-markupsafe
# dexter                                   python-mutagen
# distrobox                                python-packaging
# dnsrobocert                              python-pycurl
# dolphie                                  python-pyparsing
# dotnet@6                                 python-pyproject-hooks
# dovi_tool                                python-pytz
# driftwood                                python-tk@3.11
# dronedb                                  python-toml
# dsda-doom                                python-typing-extensions
# dstack                                   pyyaml
# dtools                                   qdmr
# dufs                                     quantum++
# dutree                                   quartz-wm
# dynein                                   quictls
# dysk                                     quilt-installer
# dzr                                      rdb
# ebook2cw                                 recoverpy
# echidna                                  renovate
# ecoji                                    resvg
# elfx86exts                               retdec
# emqx                                     rio
# enchive                                  ripsecrets
# enpass-cli                               riscv64-elf-binutils
# envd                                     riscv64-elf-gcc
# erdtree                                  riscv64-elf-gdb
# erg                                      risor
# erigon                                   rnr
# erlang@25                                roadrunner
# espflash                                 roblox-ts
# evtx                                     rojo
# eza                                      rome
# falco                                    rpmspectool
# falcoctl                                 rtx
# fastfetch                                ruby@3.1
# fastgron                                 ruff
# feishu2md                                ruff-lsp
# fend                                     runme
# ferium                                   rush-parallel
# ffmpeg@5                                 rye
# fgbio                                    s3scanner
# flagd                                    sad
# flavours                                 safeint
# fonts-encodings                          sambamba
# forgit                                   sapling
# form                                     sbom-tool
# fortls                                   scala@2.13
# fred                                     schemathesis
# fuc                                      scip
# fuego-firestore                          scrapy
# fw                                       scriptisto
# fwupd                                    secp256k1
# garble                                   service-weaver
# gat                                      seven-kingdoms
# gator                                    sh4d0wup
# gcc@12                                   shaderc
# gcem                                     shodan
# gdrive-downloader                        shub
# gebug                                    shuffledns
# geometry                                 shush
# getmail6                                 sickchill
# gf                                       simdutf
# gffread                                  sing-box
# gfold                                    skaffold@1.39
# ghc@8.10                                 skeema
# ghc@9.2                                  slither-analyzer
# ghorg                                    slsa-verifier
# gickup                                   smartdns
# gismo                                    snakefmt
# git-big-picture                          sniffnet
# git-credential-oauth                     snowball
# git-machete                              socket_vmnet
# git-sync                                 solc-select
# git-tools                                solhint
# gitea                                    solr@8.11
# gitoxide                                 soplex
# gmssl                                    souffle
# go-camo                                  spacer
# go-feature-flag-relay-proxy              spectral-cli
# go-task                                  speedbump
# go@1.18                                  spek
# go@1.19                                  spotify_player
# go@1.20                                  sql-language-server
# gobackup                                 sql-migrate
# gokey                                    sqlcmd
# golines                                  sqlpage
# goread                                   ssocr
# got                                      stackql
# gotestsum                                standard
# gotestwaf                                staq
# govulncheck                              steampipe
# gradle@7                                 stepci
# grammarly-languageserver                 streamvbyte
# grantlee                                 strip-nondeterminism
# graphqxl                                 stuffbin
# grayskull                                stylelint
# grpc@1.54                                surelog
# grype                                    svlint
# guile-gnutls                             svls
# gyb                                      swift-outdated
# has                                      swiftdraw
# hck                                      syft
# hermit                                   symlinks
# hex                                      syslog-ng
# hexer                                    tailwindcss-language-server
# highway                                  talhelper
# hivex                                    taplo
# hof                                      tart
# hotbuild                                 tbls
# hoverfly                                 teip
# hpp-fcl                                  temporal
# hq                                       tern
# httm                                     terraform-graph-beautifier
# huggingface-cli                          terragrunt-atlantis-config
# hyfetch                                  tetra
# hysteria                                 textract
# hz                                       tf-profile
# ibazel                                   tfel
# iir1                                     thriftgo
# imessage-exporter                        tkey-ssh-agent
# img2pdf                                  tl-expected
# imgdiet                                  toml-test
# imgdiff                                  totp-cli
# ipget                                    touca
# ittapi                                   toxiproxy
# jbang                                    tpm
# jet                                      tproxy
# jj                                       tracy
# joern                                    trezor-bridge
# johnnydep                                trippy
# joker                                    trufflehog
# joshuto                                  trurl
# jr                                       trust-dns
# jreleaser                                trzsz-ssh
# jscpd                                    tt
# jsign                                    tut
# jsmn                                     twm
# json2ts                                  txt2man
# json2tsv                                 typescript-language-server
# judy                                     typewritten
# juicefs                                  typical
# kalign                                   typos-cli
# katana                                   typst
# keploy                                   tzdiff
# keyring                                  udp2raw-multiplatform
# killport                                 uhdm
# kitex                                    ulfius
# kor                                      uncover
# kosli-cli                                unxip
# ksops                                    urlfinder
# kubefirst                                utftex
# kubent                                   uvg266
# kubesess                                 valijson
# kubevious                                verovio
# kustomizer                               vhs
# kuttl                                    victoriametrics
# kwctl                                    video-compare
# kwok                                     vineyard
# lacework-cli                             virtualfish
# ldid-procursus                           votca
# leetup                                   vscode-langservers-extracted
# legitify                                 vulkan-extensionlayer
# lemmeknow                                vulkan-tools
# libabigail                               vulkan-utility-libraries
# libansilove                              vulkan-validationlayers
# libaribcaption                           vunnel
# libclc                                   vvdec
# libdivide                                vvenc
# libdivsufsort                            wally
# libdvbcsa                                wasm-micro-runtime
# libecpint                                waybackpy
# libemf2svg                               wazero
# libfastjson                              weasyprint
# libff                                    web-ext
# libfyaml                                 webpod
# libgedit-gtksourceview                   wget2
# libgit2@1.5                              wikibase-cli
# libgit2@1.6                              woodpecker-cli
# libgrapheme                              woof-doom
# libint                                   wpebackend-fdo
# libisofs                                 wpscan
# libjcat                                  wtfis
# liblbfgs                                 wxlua
# liblerc                                  wzprof
# liblxi                                   xbyak
# libmediainfo                             xcdiff
# libomemo-c                               xcodes
# libpaho-mqtt                             xctesthtmlreport
# libpanel                                 xe
# libpaper                                 xinit
# libplacebo                               xlsxio
# libretls                                 xmodmap
# libsais                                  xorg-server
# libshumate                               xq
# libsolv                                  xrdb
# libunibreak                              xurls
# liburing                                 xwin
# libvatek                                 yamlfmt
# libversion                               yazi
# libvisual                                yder
# libvisual-plugins                        youplot
# libvisual-projectm                       yyjson
# libwpe                                   zchunk
# libxmlb                                  zf
# libzen                                   zlint
# libzim                                   zls
# license-eye                              zpaqfranz
# licensed                                 zrok
# licenseplist                             zsh-autocomplete
# linux-headers@5.15                       zsh-autopair
# ==> Deleted Installed Formulae
# fmt ✘
#
# You have 14 outdated formulae installed.
#
# Error: Cannot install under Rosetta 2 in ARM default prefix (/opt/homebrew)!
# To rerun under ARM use:
#     arch -arm64 brew install ...
# To install under x86_64, install Homebrew into /usr/local.

# %%
# !ffmpeg -i sample_audio/metro0o.mov -ab 160k -ac 2 -ar 44100 -vn metroo.wav
# Out:
# /bin/bash: ffmpeg: command not found

# %%
# !ffmpeg -y -r {FPS} -f image2 -s 1920x1080 -i ./content/frame%d.png -i {AUDIO_FILE} -c:v libx264 -pix_fmt yuv420p metroo_movie.mp4
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0_1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, image2, from './content/frame%d.png':
#   Duration: 00:00:14.80, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc), 3840x2160, 30 fps, 30 tbr, 30 tbn
# Guessed Channel Layout for Input Stream #1.0 : stereo
# Input #1, wav, from './sample_audio/metroo.wav':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Duration: 00:00:14.82, bitrate: 1411 kb/s
#   Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, 2 channels, s16, 1411 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [image2 @ 0x15be274e0] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# [libx264 @ 0x15be2c220] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x15be2c220] profile High, level 5.1, 4:2:0, 8-bit
# [libx264 @ 0x15be2c220] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'metroo_movie.mp4':
#   Metadata:
#     encoder         : Lavf60.3.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 3840x2160, q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.3.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc60.3.100 aac
# frame=  444 fps= 28 q=-1.0 Lsize=    3541kB time=00:00:14.81 bitrate=1958.0kbits/s speed=0.945x
# video:3280kB audio:244kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.470519%
# [libx264 @ 0x15be2c220] frame I:2     Avg QP:11.31  size: 48782
# [libx264 @ 0x15be2c220] frame P:189   Avg QP:21.10  size: 10405
# [libx264 @ 0x15be2c220] frame B:253   Avg QP:24.50  size:  5113
# [libx264 @ 0x15be2c220] consecutive B-frames: 18.7% 11.3% 14.2% 55.9%
# [libx264 @ 0x15be2c220] mb I  I16..4: 88.7%  8.1%  3.2%
# [libx264 @ 0x15be2c220] mb P  I16..4:  0.3%  0.9%  0.6%  P16..4:  1.0%  0.6%  0.3%  0.0%  0.0%    skip:96.3%
# [libx264 @ 0x15be2c220] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8:  2.0%  0.7%  0.2%  direct: 0.0%  skip:96.8%  L0:52.1% L1:43.7% BI: 4.2%
# [libx264 @ 0x15be2c220] 8x8 transform intra:34.4% inter:39.9%
# [libx264 @ 0x15be2c220] coded y,uvDC,uvAC intra: 18.8% 31.4% 27.8% inter: 0.3% 0.3% 0.2%
# [libx264 @ 0x15be2c220] i16 v,h,dc,p: 81% 18%  1%  0%
# [libx264 @ 0x15be2c220] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15%  6% 75%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x15be2c220] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 21% 31%  3%  3%  4%  4%  4%  3%
# [libx264 @ 0x15be2c220] i8c dc,h,v,p: 66% 17% 16%  1%
# [libx264 @ 0x15be2c220] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x15be2c220] ref P L0: 60.4%  4.1% 22.7% 12.9%
# [libx264 @ 0x15be2c220] ref B L0: 77.1% 17.6%  5.3%
# [libx264 @ 0x15be2c220] ref B L1: 94.7%  5.3%
# [libx264 @ 0x15be2c220] kb/s:1815.04
# [aac @ 0x15be2d180] Qavg: 510.670

# %% [markdown]
# Download the generated movie.

# %%
# from google.colab import files
# files.download('movie.mp4')
